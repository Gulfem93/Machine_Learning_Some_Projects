# %% [markdown]
# ### 1) Introduction

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Customer_Behaviour.csv")

# %%
data[data["Purchased"] == 1].head()
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 7   15694829  Female   32           150000          1
# 16  15733883    Male   47            25000          1
# 17  15617482    Male   45            26000          1
# 18  15704583    Male   46            28000          1
# 19  15621083  Female   48            29000          1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
data['Gender'].value_counts()
# Out:
# Female    204
# Male      196
# Name: Gender, dtype: int64

# %% [markdown]
# ### 2) Data Visualization

# %%
names = ["Famele", "Male"]
plt.pie(data["Gender"].value_counts(), labels=names, startangle = 90)

# Function to show the plot
plt.show()

# %%
sns.pairplot(data, hue="Purchased")
plt.show()

# %% [markdown]
# ### 3) Data Preprocessing

# %%
data["Gender"] = [0 if each == "Male" else 1 for each in data["Gender"]]

# %%
x_data = data.drop(["User ID", "Purchased"], axis = 1)
y = data["Purchased"]

# %% [markdown]
# * Normalization

# %%
x = (x_data - np.min(x_data))/(np.max(x_data) - np.min(x_data))

# %% [markdown]
# * Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 3)

# %% [markdown]
# ### 4) Classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### 4. 1. Logistic Regression

# %%
log = LogisticRegression()
log.fit(x_train, y_train)

y_head_log = log.predict(x_test)

# %% [markdown]
# #### 4.2. KNN

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train, y_train)

y_head_knn = knn.predict(x_test)

# %%
score_list = []

for each in range(1, 30):
    knn2 = KNeighborsClassifier(n_neighbors = each)
    knn2.fit(x_train, y_train)
    score_list.append(knn2.score(x_test, y_test))

plt.plot(range(1, 30), score_list)
plt.xlabel("k value")
plt.ylabel("accurancy")
plt.show()

# %% [markdown]
# #### 4.3. Decision Tree

# %%
tree = DecisionTreeClassifier()
tree.fit(x_train, y_train)

y_head_tree = tree.predict(x_test)

# %% [markdown]
# #### 4.4. Random Forest Classification

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)

y_head_rf = rf.predict(x_test)

# %% [markdown]
# #### Accuracy

# %%
print("Logistic Regression accuracy: {}".format(log.score(x_test, y_test)))
print("KNN accuracy: {}".format(knn.score(x_test, y_test)))
print("Decision Tree accuracy: {}".format(tree.score(x_test, y_test)))
print("Random Rorest accuracy: {}".format(rf.score(x_test, y_test)))
# Out:
# Logistic Regression accuracy: 0.85
# KNN accuracy: 0.9
# Decision Tree accuracy: 0.8625
# Random Rorest accuracy: 0.875

# %% [markdown]
# #### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
cm_log = confusion_matrix(y_test, y_head_log)

f, ax = plt.subplots(figsize = (5, 5))
sns.heatmap(cm_log, annot = True, linewidths = 0.5, linecolor = "red", fmt = "0.0f", ax = ax)
plt.xlabel("y_predict")
plt.ylabel("y_true")
plt.title("Logistic Regression Confusion Matrix")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cm_knn = confusion_matrix(y_test, y_head_knn)

f, ax = plt.subplots(figsize = (5, 5))
sns.heatmap(cm_knn, annot = True, linewidths = 0.5, linecolor = "red", fmt = "0.0f", ax = ax)
plt.xlabel("y_predict")
plt.ylabel("y_true")
plt.title("KNN Confusion Matrix")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cm_tree = confusion_matrix(y_test, y_head_tree)

f, ax = plt.subplots(figsize = (5, 5))
sns.heatmap(cm_tree, annot = True, linewidths = 0.5, linecolor = "red", fmt = "0.0f", ax = ax)
plt.xlabel("y_predict")
plt.ylabel("y_true")
plt.title("Decision Tree Confusion Matrix")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cm_rf = confusion_matrix(y_test, y_head_rf)

f, ax = plt.subplots(figsize = (5, 5))
sns.heatmap(cm_rf, annot = True, linewidths = 0.5, linecolor = "red", fmt = "0.0f", ax = ax)
plt.xlabel("y_predict")
plt.ylabel("y_true")
plt.title("Random Forest Confusion Matrix")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data[data["Purchased"] == 1].head()
# Out:
#      User ID  Gender  Age  EstimatedSalary  Purchased
# 7   15694829       1   32           150000          1
# 16  15733883       0   47            25000          1
# 17  15617482       0   45            26000          1
# 18  15704583       0   46            28000          1
# 19  15621083       1   48            29000          1

# %%
data[data["Purchased"] == 0].head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       0   19            19000          0
# 1  15810944       0   35            20000          0
# 2  15668575       1   26            43000          0
# 3  15603246       1   27            57000          0
# 4  15804002       0   19            76000          0

# %% [markdown]
# #### Prediction

# %%
## 0.0, 46.0, 23000.0, -> 0.0 -> 1.0

input_data1 = (0, 46, 23000) # => 1 - purchased the product 
input_data0 = (1, 27, 57000)  # => 0 - didn't purchase.

#Changing Input Data As Numpy Array
input_data_array = np.asarray(input_data1)

# Reshape the data as we are predicting for only one instance
input_data_reshape = input_data_array.reshape(1,-1)

# Normalization the data
n = [(input_data_reshape[0][0] - np.min(x_data["Gender"]))/(np.max(x_data["Gender"]) - np.min(x_data["Gender"])), 
    (input_data_reshape[0][1] - np.min(x_data["Age"]))/(np.max(x_data["Age"]) - np.min(x_data["Age"])),
    (input_data_reshape[0][2] - np.min(x_data["EstimatedSalary"]))/(np.max(x_data["EstimatedSalary"]) - np.min(x_data["EstimatedSalary"]))]

n = np.asarray(n).reshape(-1, 1)
n = n.reshape(1, 3)

std_data = n

# Prediction
prediction = knn.predict(std_data)
#print(prediction)

if prediction == 0:
    print("Person didn't purchase")
else:
    print('Person purchased the product')
# Out:
# Person purchased the product
