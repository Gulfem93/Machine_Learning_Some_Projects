# %% [markdown]
# ### 1) Introduction

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("segmentation_data.csv")

# %%
data.head()
# Out:
#           ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2000 non-null   int64
#  1   Sex              2000 non-null   int64
#  2   Marital status   2000 non-null   int64
#  3   Age              2000 non-null   int64
#  4   Education        2000 non-null   int64
#  5   Income           2000 non-null   int64
#  6   Occupation       2000 non-null   int64
#  7   Settlement size  2000 non-null   int64
# dtypes: int64(8)
# memory usage: 125.1 KB

# %%
data.isnull().sum()
# Out:
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %% [markdown]
# ### 2) Visualization

# %%
data.hist(figsize =(10,10))
plt.show()

# %%
plt.scatter(data["Age"], data["Income"])
plt.xlabel("Age")
plt.ylabel("Income")
plt.show()

# %% [markdown]
# ### 3) Data Preprocessing

# %%
data.drop(["ID"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    Sex  Marital status  Age  Education  Income  Occupation  Settlement size
# 0    0               0   67          2  124670           1                2
# 1    1               1   22          1  150773           1                2
# 2    0               0   49          1   89210           0                0
# 3    0               0   45          1  171565           1                1
# 4    0               0   53          1  149031           1                1

# %% [markdown]
# ### 4) Clustering

# %% [markdown]
# #### 4.1. KMeans

# %%
from sklearn.cluster import KMeans

cwss = []

for i in range(1, 15):
    kmean = KMeans(n_clusters = i)
    kmean.fit(data)
    cwss.append(kmean.inertia_)

plt.plot(range(1, 15), cwss)
plt.xlabel('Number of cluster')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# - n = 3 için

# %%
kmean2 = KMeans(n_clusters = 3)
cluster = kmean2.fit_predict(data)

data["kmean_label"] = cluster

# %%
plt.scatter(data["Age"], data["Income"], c = data["kmean_label"])
plt.xlabel("Age")
plt.ylabel("Income")
plt.show()

# %%
f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)

ax.scatter(data["Age"], data["Income"])
plt.xlabel("Age")
plt.ylabel("Income")

ax2.scatter(data["Age"], data["Income"], c = data["kmean_label"])
plt.xlabel("Age")
plt.ylabel("Income")
plt.show()

# %% [markdown]
# #### 4.2. Hierarchy Clustering

# %% [markdown]
# #### Dendogram

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

merg = linkage(data.iloc[50:120,:], method = "single")
dendrogram(merg, leaf_rotation = 90, leaf_font_size = 6)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

hc = AgglomerativeClustering(n_clusters = 3, affinity = "euclidean", linkage = "ward")
data["hc_label"] = hc.fit_predict(data)

# %%
plt.scatter(data["Age"], data["Income"], c = data["hc_label"])
plt.xlabel("Age")
plt.ylabel("Income")
plt.show()

# %%
f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)

ax.scatter(data["Age"], data["Income"])
plt.xlabel("Age")
plt.ylabel("Income")

ax2.scatter(data["Age"], data["Income"], c = data["hc_label"])
plt.xlabel("Age")
plt.ylabel("Income")
plt.show()
